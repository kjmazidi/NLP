# %% [markdown]
# ### This notebook shows ways to load data in Colab

# %% [markdown]
# ### Example 1: Select a file from your computer
#
# The first code block below will pop up a dialog box for you to choose a file from your computer. This makes the file available in colab.
#
# The second code block shows you how to read it in with pandas.
#
# Note that the first block may not work if you are using a browser other than Chrome. It also may not work if you have popups blocked.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2f70fdbc-682c-4261-beeb-054b097bfaf6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2f70fdbc-682c-4261-beeb-054b097bfaf6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
data = pd.read_csv('/content/Heart.csv')
data.head()
# Out:
#    ID  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0   1   63    1       typical     145   233    1        2    150      0
# 1   2   67    1  asymptomatic     160   286    0        2    108      1
# 2   3   67    1  asymptomatic     120   229    0        2    129      1
# 3   4   37    1    nonanginal     130   250    0        0    187      0
# 4   5   41    0    nontypical     130   204    0        2    172      0
#
#    Oldpeak  Slope   Ca        Thal  AHD
# 0      2.3      3  0.0       fixed   No
# 1      1.5      2  3.0      normal  Yes
# 2      2.6      2  2.0  reversable  Yes
# 3      3.5      3  0.0      normal   No
# 4      1.4      1  0.0      normal   No

# %% [markdown]
# ### Example 2
#
# This next example shows how to access files that were downloaded from [here](https://download.pytorch.org/tutorial/data.zip) and saved to a folder called "Colab Notebooks/PT/data/names" in Google Drive
#
# When you run this, you will get several pop-up screens from Google to verify that you have access to your folder.
#
# These files are used in [this PyTorch tutorial](https://colab.research.google.com/github/pytorch/tutorials/blob/gh-pages/_downloads/13b143c2380f4768d9432d808ad50799/char_rnn_classification_tutorial.ipynb#scrollTo=u4E_udA5-YuK) if you are interested.

# %%
# how to attach a Google drive folder in Colab
# modify the folder structure to fit your drive
# the '/content/drive/My Drive' portion of the path below just accesses your drive
# the folder 'names' was within folder 'PT' which is in folder 'Colab Notebooks'

import os

from google.colab import drive
drive.mount('/content/drive/')

print(os.listdir('/content/drive/My Drive/Colab Notebooks/PT/data/names'))
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# ['Irish.txt', 'Scottish.txt', 'Spanish.txt', 'Greek.txt', 'Polish.txt', 'Japanese.txt', 'Russian.txt', 'Portuguese.txt', 'Korean.txt', 'Italian.txt', 'Chinese.txt', 'German.txt', 'English.txt', 'French.txt', 'Dutch.txt', 'Czech.txt', 'Arabic.txt', 'Vietnamese.txt']

# %%
# now to prevent having to type so much in accessing folders, change directory

os.chdir('/content/drive/My Drive/Colab Notebooks/PT/data/names/')
# !ls
# Out:
# Arabic.txt   Dutch.txt	  German.txt  Italian.txt   Polish.txt	    Scottish.txt
# Chinese.txt  English.txt  Greek.txt   Japanese.txt  Portuguese.txt  Spanish.txt
# Czech.txt    French.txt   Irish.txt   Korean.txt    Russian.txt     Vietnamese.txt

# %% [markdown]
# Colab has some useful features for file management. Notice the folder icon to the left. Click that, then notice the folder icon up top with the Drive symbol. From there you can upload, download, etc.

# %% [markdown]
# ### Example 3
#
# The following example changed the Drive dirctory to a location where another file could be read using pandas.

# %%
import pandas as pd

os.chdir('/content/drive/My Drive/Colab Notebooks/TF Course Code/data')

df = pd.read_csv('Boston.csv')
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2
