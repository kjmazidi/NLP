# %% [markdown]
# # Web crawler - almost
#
# One approach to building a web crawler is to start with a starter page and extract all links from that page and put them in a queue. Then:
#
# * go to each link in the queue
# * scape all links and add to the queue
#
# This could go on forever, or until you decide to stop.
#
# In the next cell we see an initial approach to a crawler for our project which simply scrapes links off our starter page. The code uses the Python library BeautifulSoup as well as the Python **requests** module. You may need to install BeautifulSoup.

# %%
from bs4 import BeautifulSoup
import requests

# %%
starter_url = "https://en.wikipedia.org/wiki/Vince_Gilligan"

r = requests.get(starter_url)

data = r.text
soup = BeautifulSoup(data)

counter = 0
# write urls to a file
with open('urls.txt', 'w') as f:
    for link in soup.find_all('a'):
        print(link.get('href'))
        f.write(str(link.get('href')) + '\n\n')
        if counter > 20:
            break
        counter += 1

# end of program
print("end of crawler")
# Out:
# None
# #mw-head
# #searchInput
# /wiki/Vince_Gill
# /wiki/File:Vince_Gilligan_by_Gage_Skidmore_3.jpg
# /wiki/San_Diego_Comic-Con
# /wiki/Richmond,_Virginia
# /wiki/Tisch_School_of_the_Arts
# #cite_note-chesterfield-1
# /wiki/AMC_(TV_channel)
# /wiki/Breaking_Bad
# /wiki/Spin-off_(media)
# /wiki/Better_Call_Saul
# /wiki/The_X-Files
# /wiki/The_Lone_Gunmen_(TV_series)
# /wiki/Primetime_Emmy_Awards
# /wiki/Writers_Guild_of_America_Awards
# /wiki/Critics%27_Choice_Television_Awards
# /wiki/Producers_Guild_of_America_Awards
# /wiki/Directors_Guild_of_America_Award
# /wiki/British_Academy_of_Film_and_Television_Arts
# /wiki/Hancock_(film)
# end of crawler

# %% [markdown]
# Looking at those links, there are a lot that we don't want. The following rewrites the code, narrowing down what is saved.

# %%
#starter_url = "https://www.google.com/search?q=vince+gilligan&rlz=1C5CHFA_enUS584US584&oq=vince+&aqs=chrome.0.69i59j69i60j69i65j69i57j69i61j69i60.1220j0j7&sourceid=chrome&ie=UTF-8"

#r = requests.get(starter_url)

#data = r.text
#soup = BeautifulSoup(data)


# write urls to a file
with open('urls.txt', 'w') as f:
    for link in soup.find_all('a'):
        link_str = str(link.get('href'))
        print(link_str)
        if 'Gilligan' in link_str or 'gilligan' in link_str:
            if link_str.startswith('/url?q='):
                link_str = link_str[7:]
                print('MOD:', link_str)
            if '&' in link_str:
                i = link_str.find('&')
                link_str = link_str[:i]
            if link_str.startswith('http') and 'google' not in link_str:
                f.write(link_str + '\n')

# end of program
print("end of crawler")
# Out:
# None
# #mw-head
# #searchInput
# /wiki/Vince_Gill
# /wiki/File:Vince_Gilligan_by_Gage_Skidmore_3.jpg
# /wiki/San_Diego_Comic-Con
# /wiki/Richmond,_Virginia
# /wiki/Tisch_School_of_the_Arts
# #cite_note-chesterfield-1
# /wiki/AMC_(TV_channel)
# /wiki/Breaking_Bad
# /wiki/Spin-off_(media)
# /wiki/Better_Call_Saul
# /wiki/The_X-Files
# /wiki/The_Lone_Gunmen_(TV_series)
# /wiki/Primetime_Emmy_Awards
# /wiki/Writers_Guild_of_America_Awards
# /wiki/Critics%27_Choice_Television_Awards
# /wiki/Producers_Guild_of_America_Awards
# /wiki/Directors_Guild_of_America_Award
# /wiki/British_Academy_of_Film_and_Television_Arts
# /wiki/Hancock_(film)
# /wiki/El_Camino:_A_Breaking_Bad_Movie
# #Early_life
# #Education
# #Career
# #The_X-Files_and_The_Lone_Gunmen
# #Breaking_Bad_and_Better_Call_Saul
# #Other_work
# #Personal_life
# #Filmography
# #Film
# #Television
# #Production_staff
# #Writer
# #Acting
# #Awards_and_nominations
# #References
# #External_links
# /w/index.php?title=Vince_Gilligan&action=edit&section=1
# /wiki/Richmond,_Virginia
# /wiki/Claims_adjuster
# #cite_note-nytimes-2
# /wiki/Farmville,_Virginia
# /wiki/Chesterfield_County,_Virginia
# /wiki/Laboratory_school
# /wiki/Longwood_College
# /wiki/J._P._Wynne_High_School
# /wiki/Walter_White_(Breaking_Bad)
# #cite_note-3
# #cite_note-chesterfield-1
# #cite_note-amctv1-4
# #cite_note-longwood-5
# /wiki/Angus_Wall
# /wiki/Super_8_film_cameras
# /wiki/Science_fiction
# #cite_note-richmondmag-6
# /wiki/University_of_Virginia
# #cite_note-chesterfield-1
# #cite_note-richmondmag-6
# /wiki/Film_noir
# /wiki/John_Wayne
# /wiki/Clint_Eastwood
# #cite_note-richmondmag-6
# /wiki/Interlochen_Center_for_the_Arts
# #cite_note-chesterfield-1
# /w/index.php?title=Vince_Gilligan&action=edit&section=2
# /wiki/Lloyd_C._Bird_High_School
# /wiki/NYU
# /wiki/Tisch_School_of_the_Arts
# /wiki/Bachelor_of_Fine_Arts
# /wiki/Film_production
# #cite_note-7
# /wiki/Home_Fries
# #cite_note-amctv1-4
# /wiki/Mark_Johnson_(producer)
# #cite_note-richmondmag-6
# /w/index.php?title=Vince_Gilligan&action=edit&section=3
# /w/index.php?title=Vince_Gilligan&action=edit&section=4
# /wiki/The_X-Files_(franchise)
# /wiki/Fox_Broadcasting_Company
# /wiki/The_X-Files
# /wiki/Soft_Light_(The_X-Files)
# #cite_note-8
# /wiki/The_Lone_Gunmen_(TV_Series)
# /w/index.php?title=Vince_Gilligan&action=edit&section=5
# /wiki/Breaking_Bad
# /wiki/Better_Call_Saul
# /wiki/File:Vince_Gilligan_2010.jpg
# /wiki/File:Vince_Gilligan_2010.jpg
# /wiki/AMC_(TV_network)
# /wiki/Breaking_Bad
# /wiki/Hero
# /wiki/Villain
# #cite_note-grantland-9
# /wiki/Walter_White_(Breaking_Bad)
# /wiki/Goodbye,_Mr._Chips
# /wiki/Tony_Montana
# #cite_note-Bowles0713-10
# /wiki/Weeds_(TV_series)
# #cite_note-huffington-weeds-11
# #cite_note-grantland-9
# /wiki/Writers_Guild_of_America
# /wiki/Box_Cutter_(Breaking_Bad)
# #cite_note-12
# #cite_note-13
# #cite_note-14
# /wiki/Primetime_Emmy_Award_for_Outstanding_Drama_Series
# /wiki/Directors_Guild_of_America_Award_for_Outstanding_Directing_%E2%80%93_Drama_Series
# /wiki/Felina_(Breaking_Bad)
# #cite_note-15
# /wiki/Sony_Pictures_Television
# /wiki/Better_Call_Saul
# /wiki/Saul_Goodman_(Breaking_Bad)
# /wiki/Walter_White_(Breaking_Bad)
# /wiki/Bob_Odenkirk
# #cite_note-BCS_NY-16
# /wiki/Peter_Gould
# /wiki/Showrunner
# /wiki/Uno_(Better_Call_Saul)
# #cite_note-cablerecord-17
# #cite_note-18
# /wiki/El_Camino:_A_Breaking_Bad_Movie
# #cite_note-19
# /w/index.php?title=Vince_Gilligan&action=edit&section=6
# /wiki/Romantic_comedy
# /wiki/Wilder_Napalm
# /wiki/Home_Fries_(film)
# /wiki/Drew_Barrymore
# /wiki/Luke_Wilson
# #cite_note-20
# /wiki/Chris_Carter_(screenwriter)
# /wiki/Harsh_Realm
# /wiki/Police_procedural
# /wiki/Robbery_Homicide_Division
# /wiki/American_Broadcasting_Company
# /wiki/Night_Stalker_(TV_series)
# /wiki/Frank_Spotnitz
# /wiki/Sci-fi
# /wiki/A.M.P.E.D.
# /wiki/Will_Smith
# /wiki/Hancock_(film)
# #cite_note-21
# /wiki/VCR_Maintenance_and_Educational_Publishing
# /wiki/Community_(season_5)
# /wiki/NBC
# /wiki/Community_(TV_series)
# #cite_note-22
# /wiki/CBS
# /wiki/David_Shore
# /wiki/Battle_Creek_(TV_series)
# /wiki/Showrunner
# #cite_note-BC_NYT-23
# #cite_note-24
# #cite_note-25
# /w/index.php?title=Vince_Gilligan&action=edit&section=7
# #cite_note-nytimes-2
# /wiki/Catholic
# #cite_note-26
# #cite_note-nytimes.com-27
# #cite_note-nytimes.com-27
# /w/index.php?title=Vince_Gilligan&action=edit&section=8
# /wiki/File:Vince_Gilligan_and_Aaron_Paul_cropped.jpg
# /wiki/File:Vince_Gilligan_and_Aaron_Paul_cropped.jpg
# /wiki/Aaron_Paul
# /wiki/36th_Saturn_Awards
# /w/index.php?title=Vince_Gilligan&action=edit&section=9
# /wiki/Wilder_Napalm
# /wiki/Home_Fries_(film)
# /wiki/Hancock_(film)
# /wiki/El_Camino:_A_Breaking_Bad_Movie
# /w/index.php?title=Vince_Gilligan&action=edit&section=10
# /w/index.php?title=Vince_Gilligan&action=edit&section=11
# /wiki/The_X-Files
# /wiki/Harsh_Realm
# /wiki/The_X-Files
# /wiki/The_Lone_Gunmen_(TV_series)
# /wiki/A.M.P.E.D.
# /wiki/Television_pilot
# /wiki/Breaking_Bad
# /wiki/Better_Call_Saul
# /wiki/Battle_Creek_(TV_series)
# /w/index.php?title=Vince_Gilligan&action=edit&section=12
# /wiki/The_X-Files
# /wiki/Soft_Light_(The_X-Files)
# /wiki/Pusher_(The_X-Files)
# /wiki/Unruhe
# /wiki/Paper_Hearts
# /wiki/Leonard_Betts_(X-Files_episode)
# /wiki/John_Shiban
# /wiki/Frank_Spotnitz
# /wiki/Memento_Mori_(The_X-Files)
# /wiki/Chris_Carter_(screenwriter)
# /wiki/Frank_Spotnitz
# /wiki/John_Shiban
# /wiki/Small_Potatoes_(The_X-Files)
# /wiki/Unusual_Suspects_(The_X-Files)
# /wiki/Christmas_Carol_(The_X-Files)
# /wiki/John_Shiban
# /wiki/Frank_Spotnitz
# /wiki/Emily_(The_X-Files)
# /wiki/John_Shiban
# /wiki/Frank_Spotnitz
# /wiki/Kitsunegari
# /wiki/Tim_Minear
# /wiki/Bad_Blood_(The_X-Files)
# /wiki/Folie_a_Deux_(The_X-Files)
# /wiki/Drive_(The_X-Files)
# /wiki/Dreamland_(The_X-Files)
# /wiki/John_Shiban
# /wiki/Frank_Spotnitz
# /wiki/Dreamland_(The_X-Files)
# /wiki/John_Shiban
# /wiki/Frank_Spotnitz
# /wiki/Tithonus_(The_X-Files)
# /wiki/Monday_(The_X-Files)
# /wiki/John_Shiban
# /wiki/Three_of_a_Kind_(The_X-Files)
# /wiki/John_Shiban
# /wiki/Field_Trip_(The_X-Files)
# /wiki/John_Shiban
# /wiki/Frank_Spotnitz
# /wiki/Hungry_(The_X-Files)
# /wiki/Millennium_(The_X-Files)
# /wiki/Frank_Spotnitz
# /wiki/The_Amazing_Maleeni
# /wiki/John_Shiban
# /wiki/Frank_Spotnitz
# /wiki/X-Cops_(The_X-Files)
# /wiki/Theef
# /wiki/John_Shiban
# /wiki/Frank_Spotnitz
# /wiki/Je_Souhaite
# /wiki/Roadrunners_(The_X-Files)
# /wiki/The_Lone_Gunmen_(TV_series)
# /wiki/The_X-Files
# /wiki/John_Doe_(The_X-Files)
# /wiki/Jump_the_Shark_(The_X-Files)
# /wiki/John_Shiban
# /wiki/Frank_Spotnitz
# /wiki/Sunshine_Days
# /wiki/Robbery_Homicide_Division
# /wiki/Todd_A._Kessler
# /wiki/Michael_Mann_(director)
# /wiki/Night_Stalker_(TV_series)
# /wiki/Frank_Spotnitz
# /wiki/Breaking_Bad
# /wiki/Pilot_(Breaking_Bad)
# /wiki/Cat%27s_in_the_Bag...
# /wiki/...And_the_Bag%27s_in_the_River
# /wiki/Cancer_Man_(Breaking_Bad)
# /wiki/Peekaboo_(Breaking_Bad)
# /wiki/ABQ_(Breaking_Bad)
# /wiki/No_Mas_(Breaking_Bad)
# /wiki/Full_Measure_(Breaking_Bad)
# /wiki/Box_Cutter_(Breaking_Bad)
# /wiki/End_Times_(Breaking_Bad)
# /wiki/Face_Off_(Breaking_Bad)
# /wiki/Live_Free_or_Die_(Breaking_Bad)
# /wiki/Madrigal_(Breaking_Bad)
# /wiki/Felina_(Breaking_Bad)
# /wiki/Battle_Creek_(TV_series)
# /wiki/David_Shore
# /wiki/Better_Call_Saul
# /wiki/Uno_(Better_Call_Saul)
# /wiki/Peter_Gould
# /wiki/Klick_(Better_Call_Saul)
# /wiki/Mabel_(Better_Call_Saul)
# /wiki/Witness_(Better_Call_Saul)
# /wiki/Wiedersehen
# /wiki/Bagman_(Better_Call_Saul)
# /w/index.php?title=Vince_Gilligan&action=edit&section=13
# /wiki/Community_(TV_series)
# /wiki/VCR_Maintenance_and_Educational_Publishing
# /wiki/Comedy_Bang!_Bang!_(TV_series)
# /wiki/Penn_Zero:_Part-Time_Hero
# /wiki/American_Dad!
# /wiki/What_Just_Happened%3F%3F!_with_Fred_Savage
# /w/index.php?title=Vince_Gilligan&action=edit&section=14
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_
# /wiki/Template:WritersGuildofAmericaEpisodicDramaScreenplay_2000s
# /wiki/Template_talk:WritersGuildofAmericaEpisodicDramaScreenplay_2000s
# https://en.wikipedia.org/w/index.php?title=Template:WritersGuildofAmericaEpisodicDramaScreenplay_2000s&action=edit
# /wiki/Writers_Guild_of_America_Award_for_Television:_Episodic_Drama
# /wiki/Rick_Cleveland
# /wiki/Aaron_Sorkin
# /wiki/In_Excelsis_Deo
# /wiki/Tim_Van_Patten
# /wiki/Terence_Winter
# /wiki/Pine_Barrens_(The_Sopranos)
# /wiki/Dawn_Prestwich
# /wiki/Nicole_Yorkin
# /wiki/Evan_Katz
# /wiki/Debora_Cahn
# /wiki/Lawrence_Kaplow
# /wiki/Autopsy_(House)
# /wiki/Mark_V._Olsen
# /wiki/Will_Scheffer
# /wiki/Terence_Winter
# /wiki/The_Second_Coming_(The_Sopranos)
# None
# /wiki/Pilot_(Breaking_Bad)
# /wiki/David_Foster_(writer)
# /wiki/Russel_Friend
# /wiki/Garrett_Lerner
# /wiki/David_Shore
# /wiki/Broken_(House)
# /wiki/Template:WritersGuildofAmericaEpisodicDramaScreenplay
# /wiki/Template:WritersGuildofAmericaEpisodicDramaScreenplay_1960s
# /wiki/Template:WritersGuildofAmericaEpisodicDramaScreenplay_1970s
# /wiki/Template:WritersGuildofAmericaEpisodicDramaScreenplay_1980s
# /wiki/Template:WritersGuildofAmericaEpisodicDramaScreenplay_1990s
# /wiki/Template:WritersGuildofAmericaEpisodicDramaScreenplay_2000s
# /wiki/Template:WritersGuildofAmericaEpisodicDramaScreenplay_2010s
# /wiki/Template:WritersGuildofAmericaEpisodicDramaScreenplay_2010s
# /wiki/Template_talk:WritersGuildofAmericaEpisodicDramaScreenplay_2010s
# https://en.wikipedia.org/w/index.php?title=Template:WritersGuildofAmericaEpisodicDramaScreenplay_2010s&action=edit
# /wiki/Writers_Guild_of_America_Award_for_Television:_Episodic_Drama
# /wiki/Erin_Levy
# /wiki/The_Chrysanthemum_and_the_Sword_(Mad_Men)
# None
# /wiki/Box_Cutter_(Breaking_Bad)
# /wiki/Henry_Bromell
# /wiki/The_Good_Soldier_(Homeland)
# /wiki/Semi_Chellas
# /wiki/Matthew_Weiner
# /wiki/The_Other_Woman_(Mad_Men)
# /wiki/Gennifer_Hutchison
# /wiki/Confessions_(Breaking_Bad)
# /wiki/Robert_King_(writer)
# /wiki/Michelle_King
# /wiki/The_Last_Call_(The_Good_Wife)
# None
# /wiki/Peter_Gould
# /wiki/Uno_(Better_Call_Saul)
# /wiki/Gordon_Smith_(screenwriter)
# /wiki/Chicanery_(Better_Call_Saul)
# /wiki/Alex_Gansa
# /wiki/Paean_to_the_People
# /wiki/Tern_Haven
# /wiki/Template:WritersGuildofAmericaEpisodicDramaScreenplay
# /wiki/Template:WritersGuildofAmericaEpisodicDramaScreenplay_1960s
# /wiki/Template:WritersGuildofAmericaEpisodicDramaScreenplay_1970s
# /wiki/Template:WritersGuildofAmericaEpisodicDramaScreenplay_1980s
# /wiki/Template:WritersGuildofAmericaEpisodicDramaScreenplay_1990s
# /wiki/Template:WritersGuildofAmericaEpisodicDramaScreenplay_2000s
# /wiki/Template:WritersGuildofAmericaEpisodicDramaScreenplay_2010s
# /wiki/Template:DirectorsGuildofAmericaOutstandingDirectingDramaSeries
# /wiki/Template_talk:DirectorsGuildofAmericaOutstandingDirectingDramaSeries
# https://en.wikipedia.org/w/index.php?title=Template:DirectorsGuildofAmericaOutstandingDirectingDramaSeries&action=edit
# /wiki/Directors_Guild_of_America_Award_for_Outstanding_Directing_%E2%80%93_Drama_Series
# /wiki/Daniel_Petrie
# /wiki/Robert_Butler_(director)
# /wiki/Charles_S._Dubin
# /wiki/James_Cellan_Jones
# /wiki/Jennie:_Lady_Randolph_Churchill
# /wiki/Glenn_Jordan
# /wiki/John_Erman
# /wiki/Gene_Reynolds
# /wiki/Roger_Young_(director)
# /wiki/Roger_Young_(director)
# /wiki/Robert_Butler_(director)
# /wiki/Hill_Street_Station
# /wiki/David_Anspaugh
# /wiki/Jeff_Bleckner
# /wiki/Thomas_Carter_(director)
# /wiki/Will_Mackenzie
# /wiki/Will_Mackenzie
# /wiki/Marshall_Herskovitz
# /wiki/Thirtysomething
# /wiki/Marshall_Herskovitz
# /wiki/Eric_Laneuville
# /wiki/Michael_Zinberg
# /wiki/Eric_Laneuville
# /wiki/Rob_Thompson_(director)
# /wiki/Gregory_Hoblit
# /wiki/NYPD_Blue
# /wiki/Charles_Haid
# /wiki/Christopher_Chulack
# /wiki/Christopher_Chulack
# /wiki/Barbara_Kopple
# /wiki/Paris_Barclay
# /wiki/Hearts_and_Souls
# /wiki/David_Chase
# /wiki/The_Sopranos_(episode)
# /wiki/Thomas_Schlamme
# /wiki/No%C3%ABl_(The_West_Wing)
# /wiki/Alan_Ball_(screenwriter)
# /wiki/Pilot_(Six_Feet_Under)
# /wiki/John_Patterson_(director)
# /wiki/Whitecaps_(The_Sopranos)
# /wiki/Christopher_Misiano
# /wiki/Twenty_Five_(The_West_Wing)
# /wiki/Walter_Hill_(director)
# /wiki/Deadwood_(Deadwood_episode)
# /wiki/Michael_Apted
# /wiki/The_Stolen_Eagle
# /wiki/Jon_Cassar
# /wiki/Day_5:_7:00_a.m._%E2%80%93_8:00_a.m.
# /wiki/Alan_Taylor_(director)
# /wiki/Smoke_Gets_in_Your_Eyes_(Mad_Men)
# /wiki/Dan_Attias
# /wiki/Transitions_(The_Wire)
# /wiki/Lesli_Linka_Glatter
# /wiki/Guy_Walks_Into_an_Advertising_Agency
# /wiki/Martin_Scorsese
# /wiki/Boardwalk_Empire_(Boardwalk_Empire_episode)
# /wiki/Patty_Jenkins
# /wiki/Pilot_(The_Killing)
# /wiki/Rian_Johnson
# /wiki/Fifty-One
# None
# /wiki/Felina_(Breaking_Bad)
# /wiki/Lesli_Linka_Glatter
# /wiki/From_A_to_B_and_Back_Again
# /wiki/David_Nutter
# /wiki/Mother%27s_Mercy
# /wiki/Miguel_Sapochnik
# /wiki/Battle_of_the_Bastards
# /wiki/Reed_Morano
# /wiki/Adam_McKay
# /wiki/Nicole_Kassell
# /wiki/It%27s_Summer_and_We%27re_Running_Out_of_Ice
# /wiki/Help:Authority_control
# https://www.wikidata.org/wiki/Q4500#identifiers
# /wiki/Bibsys
# https://authority.bibsys.no/authority/rest/authorities/html/15007895
# /wiki/Biblioteca_Nacional_de_Espa%C3%B1a
# http://catalogo.bne.es/uhtbin/authoritybrowse.cgi?action=display&authority_id=XX1516062
# /wiki/BNF_(identifier)
# https://catalogue.bnf.fr/ark:/12148/cb14101375v
# https://data.bnf.fr/ark:/12148/cb14101375v
# /wiki/GND_(identifier)
# https://d-nb.info/gnd/140545832
# /wiki/ISNI_(identifier)
# http://isni.org/isni/0000000108596775
# /wiki/LCCN_(identifier)
# https://id.loc.gov/authorities/names/n99032272
# /wiki/National_Library_of_the_Czech_Republic
# https://aleph.nkp.cz/F/?func=find-c&local_base=aut&ccl_term=ica=xx0186183&CON_LNG=ENG
# /wiki/Royal_Library_of_the_Netherlands
# http://data.bibliotheken.nl/id/thes/p331225972
# /wiki/SNAC
# https://snaccooperative.org/ark:/99166/w6pr8xtk
# /wiki/SUDOC_(identifier)
# https://www.idref.fr/057602816
# /wiki/VIAF_(identifier)
# https://viaf.org/viaf/107230905
# /wiki/WorldCat_Identities
# https://www.worldcat.org/identities/lccn-n99032272
# https://en.wikipedia.org/w/index.php?title=Vince_Gilligan&oldid=974637138
# https://ga.wikipedia.org/wiki/Vince_Gilligan
# https://hy.wikipedia.org/wiki/%D5%8E%D5%AB%D5%B6%D5%BD_%D4%B3%D5%AB%D5%AC%D5%AB%D5%A3%D5%A1%D5%B6
# https://id.wikipedia.org/wiki/Vince_Gilligan
# https://it.wikipedia.org/wiki/Vince_Gilligan
# https://he.wikipedia.org/wiki/%D7%95%D7%99%D7%A0%D7%A1_%D7%92%D7%99%D7%9C%D7%99%D7%92%D7%90%D7%9F
# https://kk.wikipedia.org/wiki/%D0%92%D0%B8%D0%BD%D1%81_%D0%93%D0%B8%D0%BB%D0%BB%D0%B8%D0%B3%D0%B0%D0%BD
# https://arz.wikipedia.org/wiki/%D9%81%D9%8A%D9%86%D8%B3_%D8%AC%D9%8A%D9%84%D9%8A%D8%AC%D8%A7%D9%86
# https://nl.wikipedia.org/wiki/Vince_Gilligan
# https://ja.wikipedia.org/wiki/%E3%83%B4%E3%82%A3%E3%83%B3%E3%82%B9%E3%83%BB%E3%82%AE%E3%83%AA%E3%82%AC%E3%83%B3
# https://no.wikipedia.org/wiki/Vince_Gilligan
# https://pl.wikipedia.org/wiki/Vince_Gilligan
# https://pt.wikipedia.org/wiki/Vince_Gilligan
# https://ro.wikipedia.org/wiki/Vince_Gilligan
# https://ru.wikipedia.org/wiki/%D0%93%D0%B8%D0%BB%D0%BB%D0%B8%D0%B3%D0%B0%D0%BD,_%D0%92%D0%B8%D0%BD%D1%81
# https://sq.wikipedia.org/wiki/Vince_Gilligan
# https://simple.wikipedia.org/wiki/Vince_Gilligan
# https://sk.wikipedia.org/wiki/Vince_Gilligan
# https://sl.wikipedia.org/wiki/Vince_Gilligan
# https://fi.wikipedia.org/wiki/Vince_Gilligan
# https://sv.wikipedia.org/wiki/Vince_Gilligan
# https://tr.wikipedia.org/wiki/Vince_Gilligan
# https://uk.wikipedia.org/wiki/%D0%92%D1%96%D0%BD%D1%81_%D0%93%D1%96%D0%BB%D0%BB%D1%96%D0%B3%D0%B0%D0%BD
# https://ur.wikipedia.org/wiki/%D9%88%D9%86%D8%B3_%DA%AF%D9%84%DB%8C%DA%AF%DB%8C%D9%86
# https://zh.wikipedia.org/wiki/%E6%96%87%E6%96%AF%C2%B7%E5%90%89%E5%88%A9%E6%A0%B9
# https://www.wikidata.org/wiki/Special:EntityPage/Q4500#sitelinks-wikipedia
# //en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
# //creativecommons.org/licenses/by-sa/3.0/
# //foundation.wikimedia.org/wiki/Terms_of_Use
# //foundation.wikimedia.org/wiki/Privacy_policy
# //www.wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# //en.m.wikipedia.org/w/index.php?title=Vince_Gilligan&mobileaction=toggle_view_mobile
# https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute
# https://stats.wikimedia.org/#/en.wikipedia.org
# https://foundation.wikimedia.org/wiki/Cookie_statement
# https://wikimediafoundation.org/
# https://www.mediawiki.org/
# end of crawler

# %% [markdown]
# Let's look at the urls that actually got saved.

# %%
with open('urls.txt', 'r') as f:
    urls = f.read().splitlines()
for u in urls:
    print(u)
# Out:
# http://www.amctv.com/shows/breaking-bad/crew/vince-gilligan
# http://www.mahalo.com/vince-gilligan
# http://www.huffingtonpost.com/2012/07/17/vince-gilligan-breaking-bad_n_1679038.html
# https://www.thewrap.com/breaking-bad-creator-vince-gilligan-staying-at-sony-tv-with-new-three-year-deal/
# https://www.theverge.com/2018/11/7/18072070/breaking-bad-spinoff-film-vince-gilligan-greenbriar
# http://nofilmschool.com/2013/10/vince-gilligan-breaking-bad-20th-austin-film-festival
# http://artsbeat.blogs.nytimes.com/2014/03/12/breaking-bad-creator-vince-gilligans-next-project-an-appearance-on-community/?_php=true
# https://www.nytimes.com/2013/09/26/business/media/breaking-bad-creator-gilligan-in-deal-for-cbs-show-battle-creek.html
# http://www.hollywoodreporter.com/live-feed/cbs-cancels-vince-gilligans-battle-794524
# https://commons.wikimedia.org/wiki/Category:Vince_Gilligan
# https://web.archive.org/web/20081219095120/http://www.amctv.com/originals/breakingbad/cast/vgilligan
# https://interviews.televisionacademy.com/interviews/vince-gilligan
# https://en.wikipedia.org/w/index.php?title=Vince_Gilligan
# https://commons.wikimedia.org/wiki/Category:Vince_Gilligan
# https://ca.wikipedia.org/wiki/Vince_Gilligan
# https://de.wikipedia.org/wiki/Vince_Gilligan
# https://et.wikipedia.org/wiki/Vince_Gilligan
# https://es.wikipedia.org/wiki/Vince_Gilligan
# https://fr.wikipedia.org/wiki/Vince_Gilligan
# https://ga.wikipedia.org/wiki/Vince_Gilligan
# https://id.wikipedia.org/wiki/Vince_Gilligan
# https://it.wikipedia.org/wiki/Vince_Gilligan
# https://nl.wikipedia.org/wiki/Vince_Gilligan
# https://no.wikipedia.org/wiki/Vince_Gilligan
# https://pl.wikipedia.org/wiki/Vince_Gilligan
# https://pt.wikipedia.org/wiki/Vince_Gilligan
# https://ro.wikipedia.org/wiki/Vince_Gilligan
# https://sq.wikipedia.org/wiki/Vince_Gilligan
# https://simple.wikipedia.org/wiki/Vince_Gilligan
# https://sk.wikipedia.org/wiki/Vince_Gilligan
# https://sl.wikipedia.org/wiki/Vince_Gilligan
# https://fi.wikipedia.org/wiki/Vince_Gilligan
# https://sv.wikipedia.org/wiki/Vince_Gilligan
# https://tr.wikipedia.org/wiki/Vince_Gilligan

# %% [markdown]
# Now to make a true crawler out of the code above, we would need to implement the queue of urls to keep crawling until some stopping criterion is reached.
#
# For your project code, crawl beyond the first page until you get 15 *relevant* urls.

# %% [markdown]
# ## crawling and scraping
#
# You can also use BeautifulSoup to get text from the urls in your url list. Let's try that on one url.

# %%
from bs4 import BeautifulSoup
import urllib.request
import re

my_url = "http://deadline.com/2017/08/better-call-saul-vince-gilligan-emmys-interview-news-1202151940/"

# function to determine if an element is visible
def visible(element):
    if element.parent.name in ['style', 'script', '[document]', 'head', 'title']:
        return False
    elif re.match('<!--.*-->', str(element.encode('utf-8'))):
        return False
    return True

html = urllib.request.urlopen(my_url)
soup = BeautifulSoup(html)
data = soup.findAll(text=True)
result = filter(visible, data)
temp_list = list(result)      # list from filter
temp_str = ' '.join(temp_list)
temp_str
# Out:
# '\n <![endif] \n \n \n \n  Add to home screen for iOS  \n \n \n \n \n \n  Tile icons for Windows  \n \n \n \n  Favicons  \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n  Smart Banner start  \n \n  Smart Banner end  \n   \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n  Jetpack Open Graph Tags  \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n  End Jetpack Open Graph Tags  \n \n \n \n \n   \n \n \n \n \n \n  Swiftype Meta Tags Start  \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n
& His Approach To Directing Reality\xa0Television \n \n \n ‘Watchmen’ VFX Supervisor Erik Henry On Finding Right Visual Approach To Doctor Manhattan, Crafting Looking Glass’s Mask & Highlights Of Experience With HBO\xa0Drama \n \n \n ‘Reno 911!’s Thomas Lennon Talks ‘Cops’ Cancellation, Quibi Revival, Plans For More Seasons & Leaning Into The Politically\xa0Incorrect \n \n \n \n View All \n \n \n \n \n August 22, 2017 9:03am \n \n \n \n \n \n \n 2 Comments   \n \n \n \n \n \n Facebook \n \n \n \n Twitter \n \n \n \n  ...

# %% [markdown]
# So that's some messy text. You will want to write functions to clean up that text by removing newlines and tabs, perhaps use regex to remove wiki-style links,

# %% [markdown]
# ## finding important terms
#
# A simple way to find important words is to tokenize the text, remove stop words, punctuation and other nonimportant matter, and then do frequency counts to get the top terms. We will learn more sophisticated techniques later.
#
# You might print out the top 40 terms and then manually remove some that are not important, using your domain knowledge. Here are the 15 terms I kept. Notice that I put related terms in parenthesis so that these are my 15 topics my bot should be able to talk about.
#
# * personal (girlfriend, born, school, father, mother)
# * series
# * breaking_bad
# * better_call_saul
# * xfiles
# * write
# * produce
# * direct
# * tv (television)
# * film (movie)

# %% [markdown]
# ### building a knowledge base
#
# Assuming that you saved the cleaned documents you can loop through those and extract sentences using nltk's sentence tokenizer.

# %%
from nltk.tokenize import sent_tokenize
text = "This is a sentence. This is another sentence. Here is one more."
sents = sent_tokenize(text)
for sent in sents:
    print(sent)
# Out:
# This is a sentence.
# This is another sentence.
# Here is one more.

# %% [raw]
# Your goal for the project is to collect sentences related to each topic. I leave it up to you to decide how to store these, but I would not spend an inordinate amount of time making a complex knowledge base because you may change your mind in Part 2 when you decide what is important for the bot to "know".

# %% [markdown]
# ## sample dialog
#
# Before leaving Part 1 you should type up some possible dialogs that you want your chatbot to be able to do. These dialogs can be short interchanges that vary depending on user input. Be prepared to share a couple of possible dialogs with the class. Here are a couple:

# %% [markdown]
# Initial dialog 1
#
# Hi, I'm Fabian, a fan-bot of Vince Gilligan. I love to talk about Vince Gilligan! What is your name?
#
# 	I'm Karen.
#
# Hi Karen. Do you like Vince Gilligan?
#
# 	Yes, I am a fan of Breaking Bad and Better Call Saul.
#
# Me too! What is your favorite Vince Gilligan show?
#
# 	Oh, I don't know. It's hard to pick a favorite.
#
# If you had to choose between Breaking Bad and Better Call Saul, which would it be?
#
# 	I guess Better Call Saul, but maybe because I just watched it recently.
#
# Better Call Saul is a good choice. Did you know
# |random fact|?
#
#     Yes, I knew that.

# %% [markdown]
# Initial dialog 2
#
# Hi, I'm Fabian, a fan-bot of Vince Gilligan. I love to talk about Vince Gilligan! What is your name?
#
# 	I'm Karen.
#
# Hi Karen. Do you like Vince Gilligan?
#
# 	Not really.
#
# That's too bad! Have you seen Breaking Bad?
#
# 	Yes, I thought it was too violent.
#
# So you didn't like it because it was too violent.
#
# 	That's right.
#
# What about some of his other shows, like X-Files or Better Call Saul?
#
#     I didn't know Vince Gilligan was invoved with the X-Files.
