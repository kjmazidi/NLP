# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/kjmazidi/NLP/blob/master/Chapter_02_intro_python/03-Data-structures.ipynb)

# %% [markdown]
# ## Chapter 2 Intro to Python
# ### Notebook 3 Data Structures
#
# These general-purpose containers are essential to programming in Python:
#
# * A **list** is mutable and represented in \[square brackets]
# * A **tuple** is immutable and represented in (parenthesis)
# * A **set** is mutable and represented in { }
# * A **dict** is mutable and represented in {key:value} pairs
# * A **string** is immutable and enclosed in single, double, or triple quotes
#
# Other specialized containers include Counter, OrderedDict, deque, and many more. You can research these in [the docs](https://docs.python.org/3/library/collections.html)
#
#
# ###### Code accompanies *Natural Language Processing* by KJG Mazidi, all rights reserved.

# %% [markdown]
# #### List example: iterating over a sorted list

# %%
friends = ['Bob', 'Xavier', 'Zelda', 'Anika', 'Hamed']

for friend in sorted(friends):
    print(friend)
# Out:
# Anika
# Bob
# Hamed
# Xavier
# Zelda

# %% [markdown]
# #### List comprehension example

# %%
new_list = [x**2 for x in range(1, 10)]
new_list
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %% [markdown]
# #### Tuple example

# %%
def calc_list_stats(alist):
    min_val = min(alist)
    max_val = max(alist)
    sum_val = sum(alist)
    mean_val = sum(alist) / len(alist)
    return min_val, max_val, sum_val, mean_val

list1 = list(range(1, 10)) 

lmin, lmax, lsum, lmean = calc_list_stats(list1)  # tuple unpacking

print(lmin, lmax, lsum, lmean)
# Out:
# 1 9 45 5.0

# %% [markdown]
# #### Set example

# %%
string1 = 'The University of Texas at Dallas'.lower()

letters = set(string1)
print(letters)
# Out:
# {'d', 'v', 's', 'n', 'u', 'x', 't', 'e', 'r', ' ', 'i', 'f', 'h', 'o', 'a', 'y', 'l'}

# %% [markdown]
# #### Dict example

# %%
dict_counts = {}

for letter in letters:
    dict_counts[letter] = string1.count(letter)
    
dict_counts
# Out:
# {'d': 1,
#  'v': 1,
#  's': 3,
#  'n': 1,
#  'u': 1,
#  'x': 1,
#  't': 4,
#  'e': 3,
#  'r': 1,
#  ' ': 5,
#  'i': 2,
#  'f': 1,
#  'h': 1,
#  'o': 1,
#  'a': 4,
#  'y': 1,
#  'l': 2}

# %% [markdown]
# #### String examples

# %%
print(string1.upper())
print(string1[0].isalpha())
# Out:
# THE UNIVERSITY OF TEXAS AT DALLAS
# True

# %% [markdown]
# #### Format text and write to a file

# %%
num = 3
gpa = 3.7
name = 'Ralph'
f = open('temp.txt', 'w')
f.write(f'Name: {name:8} Favorite number is {num:d} \t GPA is {gpa:.2f}')
f.close()

# print to console
print(f'Name: {name:8} Favorite number is {num:d} \t GPA is {gpa:.2f}')
# Out:
# Name: Ralph    Favorite number is 3 	 GPA is 3.70

# %% [markdown]
# #### Read from a file

# %%
with open('temp.txt', 'r') as f:
    text = f.read()
    
print(text)
# Out:
# Name: Ralph    Favorite number is 3 	 GPA is 3.70
